# %%
import pandas as pd
import numpy as np
from bokeh.charts import Histogram, output_file, show
from bokeh.io import output_notebook
from bokeh.embed import components

# %%
#sample data
ten = np.random.normal(2000,100,5000)
ka = np.random.randint(1,10,5000)
df = pd.DataFrame({'dpc':ten,'ka':ka})

# %%
hist = Histogram(df, values='dpc', title="テスト", plot_width=400,bins = 10)
output_notebook()
show(hist)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ae094c40-cb7a-477f-86b2-7052026fc2cf">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="4ebab1eb-9603-43a2-9be5-6d5324dd7279"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ebab1eb-9603-43a2-9be5-6d5324dd7279");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ebab1eb-9603-43a2-9be5-6d5324dd7279' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d2d3f797-c615-435e-9865-36cfb37c1e49":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae58c465-d644-4fdd-8686-6aeb9c847b8c","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","color","height","x","line_alpha","fill_alpha","width","label","line_color"],"data":{"chart_index":["(2137.8, 2225.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[386.0],"label":["(2137.8, 2225.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[87.57771681781014],"x":["2181.6000000000004"],"y":[193.0]}},"id":"bcabb5c0-28b7-44de-b786-255bd624ea17","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","color","height","x","line_alpha","fill_alpha","width","label","line_color"],"data":{"chart_index":["(2225.4, 2313.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[59.0],"label":["(2225.4, 2313.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[87.57771681781014],"x":["2269.2"],"y":[29.5]}},"id":"df83df69-ca7f-44be-8531-6c14c00924c7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"01700b66-a135-4229-985a-d2c24ccbbb01","type":"ColumnDataSource"},"glyph":{"id":"e01531aa-d1a8-4f18-b1e9-59bb33aae66a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0200e6dd-3c85-42b2-acab-0912fd4f4cf8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","color","height","x","line_alpha","fill_alpha","width","label","line_color"],"data":{"chart_index":["(1612.3, 1699.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"label":["(1612.3, 1699.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[87.57771681780991],"x":["1656.1"],"y":[3.5]}},"id":"c665d964-8860-4ffd-a286-0d546014c2da","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"73eed1dd-7f83-4b5b-b891-84fe5b08033f","subtype":"Chart","type":"Plot"}},"id":"f728cd69-96a0-445b-a573-3a0de6f46651","type":"ResetTool"},{"attributes":{"data_source":{"id":"3d614e6f-c59e-46c1-8f0f-616b2f5c1d29","type":"ColumnDataSource"},"glyph":{"id":"b1c9935e-7d2b-4cc4-8b8e-13d82807e7db","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6cea80fe-3a7e-4b5f-8000-7fc7ce58495d","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"73eed1dd-7f83-4b5b-b891-84fe5b08033f","subtype":"Chart","type":"Plot"},"ticker":{"id":"0983e40d-0d28-43a9-b8a0-4659f4a5e823","type":"BasicTicker"}},"id":"bd5df147-ae96-4da8-a2ac-ac735db50c40","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"98409a60-7ae8-4970-a50b-8887c51c38df","type":"PanTool"},{"id":"6fe21092-9589-43c0-9b01-b02dca9058d6","type":"WheelZoomTool"},{"id":"004c9363-7732-4001-bd23-265cb0132ed1","type":"BoxZoomTool"},{"id":"30c5a90e-13e1-46d3-a63e-168f9e36fde2","type":"SaveTool"},{"id":"f728cd69-96a0-445b-a573-3a0de6f46651","type":"ResetTool"},{"id":"da3afa78-19ed-41d8-b658-eeafaebae58e","type":"HelpTool"}]},"id":"322a6a7c-c67c-49d0-a7c1-c811e9ca0922","type":"Toolbar"},{"attributes":{"data_source":{"id":"c665d964-8860-4ffd-a286-0d546014c2da","type":"ColumnDataSource"},"glyph":{"id":"b7a75f88-33a3-47df-bca7-4ae599e359a9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7d854ed2-085a-418e-bb46-de59839c1bfb","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"73eed1dd-7f83-4b5b-b891-84fe5b08033f","subtype":"Chart","type":"Plot"}},"id":"b9af3df7-d475-43a8-9e55-9a39e1a08401","type":"Legend"},{"attributes":{"callback":null,"column_names":["y","color","height","x","line_alpha","fill_alpha","width","label","line_color"],"data":{"chart_index":["(1787.5, 1875.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[448.0],"label":["(1787.5, 1875.1]"],"line_alp ...
